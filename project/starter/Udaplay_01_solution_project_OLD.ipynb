# %%
from pathlib import Path
from dotenv import load_dotenv
from lib.udaplay_tools import configure_udaplay_tools

load_dotenv()

from lib.udaplay_vector_store import UdaPlayVectorStore

# %%
pip install sentence_transformers
# Out:
# Requirement already satisfied: sentence_transformers in /opt/venv/lib/python3.13/site-packages (5.5.0)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in /opt/venv/lib/python3.13/site-packages (from sentence_transformers) (5.8.1)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /opt/venv/lib/python3.13/site-packages (from sentence_transformers) (1.15.0)
# Requirement already satisfied: torch>=1.11.0 in /opt/venv/lib/python3.13/site-packages (from sentence_transformers) (2.12.0)
# Requirement already satisfied: numpy>=1.20.0 in /opt/venv/lib/python3.13/site-packages (from sentence_transformers) (2.3.0)
# Requirement already satisfied: scikit-learn>=0.22.0 in /opt/venv/lib/python3.13/site-packages (from sentence_transformers) (1.8.0)
# Requirement already satisfied: scipy>=1.0.0 in /opt/venv/lib/python3.13/site-packages (from sentence_transformers) (1.17.1)
# Requirement already satisfied: typing_extensions>=4.5.0 in /opt/venv/lib/python3.13/site-packages (from sentence_transformers) (4.14.0)
# Requirement already satisfied: tqdm>=4.0.0 in /opt/venv/lib/python3.13/site-packages (from sentence_transformers) (4.67.1)
# Requirement already satisfied: filelock>=3.10.0 in /opt/venv/lib/python3.13/site-packages (from huggingface-hub>=0.23.0->sentence_transformers) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/venv/lib/python3.13/site-packages (from huggingface-hub>=0.23.0->sentence_transformers) (2025.5.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /opt/venv/lib/python3.13/site-packages (from huggingface-hub>=0.23.0->sentence_transformers) (1.5.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/venv/lib/python3.13/site-packages (from huggingface-hub>=0.23.0->sentence_transformers) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in /opt/venv/lib/python3.13/site-packages (from huggingface-hub>=0.23.0->sentence_transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /opt/venv/lib/python3.13/site-packages (from huggingface-hub>=0.23.0->sentence_transformers) (6.0.2)
# Requirement already satisfied: typer>=0.20.0 in /opt/venv/lib/python3.13/site-packages (from huggingface-hub>=0.23.0->sentence_transformers) (0.25.1)
# Requirement already satisfied: joblib>=1.3.0 in /opt/venv/lib/python3.13/site-packages (from scikit-learn>=0.22.0->sentence_transformers) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /opt/venv/lib/python3.13/site-packages (from scikit-learn>=0.22.0->sentence_transformers) (3.6.0)
# Requirement already satisfied: setuptools<82 in /opt/venv/lib/python3.13/site-packages (from torch>=1.11.0->sentence_transformers) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /opt/venv/lib/python3.13/site-packages (from torch>=1.11.0->sentence_transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /opt/venv/lib/python3.13/site-packages (from torch>=1.11.0->sentence_transformers) (3.6.1)
# Requirement already satisfied: jinja2 in /opt/venv/lib/python3.13/site-packages (from torch>=1.11.0->sentence_transformers) (3.1.6)
# Requirement already satisfied: cuda-toolkit==13.0.2 in /opt/venv/lib/python3.13/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.11.0->sentence_transformers) (13.0.2)
# Requirement already satisfied: nvidia-cublas<=13.1.1.3,>=13.1.0.3 in /opt/venv/lib/python3.13/site-packages (from torch>=1.11.0->sentence_transformers) (13.1.1.3)
# Requirement already satisfied: cuda-bindings<14,>=13.0.3 in /opt/venv/lib/python3.13/site-packages (from torch>=1.11.0->sentence_transformers) (13.2.0)
# Requirement already satisfied: nvidia-cudnn-cu13==9.20.0.48 in /opt/venv/lib/python3.13/site-packages (from torch>=1.11.0->sentence_transformers) (9.20.0.48)
# Requirement already satisfied: nvidia-cusparselt-cu13==0.8.1 in /opt/venv/lib/python3.13/site-packages (from torch>=1.11.0->sentence_transformers) (0.8.1)
# Requirement already satisfied: nvidia-nccl-cu13==2.29.7 in /opt/venv/lib/python3.13/site-packages (from torch>=1.11.0->sentence_transformers) (2.29.7)
# Requirement already satisfied: nvidia-nvshmem-cu13==3.4.5 in /opt/venv/lib/python3.13/site-packages (from torch>=1.11.0->sentence_transformers) (3.4.5)
# Requirement already satisfied: triton==3.7.0 in /opt/venv/lib/python3.13/site-packages (from torch>=1.11.0->sentence_transformers) (3.7.0)
# Requirement already satisfied: nvidia-cuda-runtime==13.0.96.* in /opt/venv/lib/python3.13/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.11.0->sentence_transformers) (13.0.96)
# Requirement already satisfied: nvidia-cufft==12.0.0.61.* in /opt/venv/lib/python3.13/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.11.0->sentence_transformers) (12.0.0.61)
# Requirement already satisfied: nvidia-cufile==1.15.1.6.* in /opt/venv/lib/python3.13/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.11.0->sentence_transformers) (1.15.1.6)
# Requirement already satisfied: nvidia-cuda-cupti==13.0.85.* in /opt/venv/lib/python3.13/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.11.0->sentence_transformers) (13.0.85)
# Requirement already satisfied: nvidia-curand==10.4.0.35.* in /opt/venv/lib/python3.13/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.11.0->sentence_transformers) (10.4.0.35)
# Requirement already satisfied: nvidia-cusolver==12.0.4.66.* in /opt/venv/lib/python3.13/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.11.0->sentence_transformers) (12.0.4.66)
# Requirement already satisfied: nvidia-cusparse==12.6.3.3.* in /opt/venv/lib/python3.13/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.11.0->sentence_transformers) (12.6.3.3)
# Requirement already satisfied: nvidia-nvjitlink==13.0.88.* in /opt/venv/lib/python3.13/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.11.0->sentence_transformers) (13.0.88)
# Requirement already satisfied: nvidia-cuda-nvrtc==13.0.88.* in /opt/venv/lib/python3.13/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.11.0->sentence_transformers) (13.0.88)
# Requirement already satisfied: nvidia-nvtx==13.0.85.* in /opt/venv/lib/python3.13/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.11.0->sentence_transformers) (13.0.85)
# Requirement already satisfied: regex>=2025.10.22 in /opt/venv/lib/python3.13/site-packages (from transformers<6.0.0,>=4.41.0->sentence_transformers) (2026.5.9)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /opt/venv/lib/python3.13/site-packages (from transformers<6.0.0,>=4.41.0->sentence_transformers) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in /opt/venv/lib/python3.13/site-packages (from transformers<6.0.0,>=4.41.0->sentence_transformers) (0.7.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /opt/venv/lib/python3.13/site-packages (from cuda-bindings<14,>=13.0.3->torch>=1.11.0->sentence_transformers) (1.5.4)
# Requirement already satisfied: anyio in /opt/venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence_transformers) (4.9.0)
# Requirement already satisfied: certifi in /opt/venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence_transformers) (2025.6.15)
# Requirement already satisfied: httpcore==1.* in /opt/venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence_transformers) (1.0.9)
# Requirement already satisfied: idna in /opt/venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence_transformers) (3.10)
# Requirement already satisfied: h11>=0.16 in /opt/venv/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence_transformers) (0.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/venv/lib/python3.13/site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence_transformers) (1.3.0)
# Requirement already satisfied: click>=8.2.1 in /opt/venv/lib/python3.13/site-packages (from typer>=0.20.0->huggingface-hub>=0.23.0->sentence_transformers) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in /opt/venv/lib/python3.13/site-packages (from typer>=0.20.0->huggingface-hub>=0.23.0->sentence_transformers) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /opt/venv/lib/python3.13/site-packages (from typer>=0.20.0->huggingface-hub>=0.23.0->sentence_transformers) (14.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /opt/venv/lib/python3.13/site-packages (from typer>=0.20.0->huggingface-hub>=0.23.0->sentence_transformers) (0.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/venv/lib/python3.13/site-packages (from jinja2->torch>=1.11.0->sentence_transformers) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/venv/lib/python3.13/site-packages (from rich>=13.8.0->typer>=0.20.0->huggingface-hub>=0.23.0->sentence_transformers) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/venv/lib/python3.13/site-packages (from rich>=13.8.0->typer>=0.20.0->huggingface-hub>=0.23.0->sentence_transformers) (2.19.1)
# Requirement already satisfied: sniffio>=1.1 in /opt/venv/lib/python3.13/site-packages (from anyio->httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence_transformers) (1.3.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/venv/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer>=0.20.0->huggingface-hub>=0.23.0->sentence_transformers) (0.1.2)
#
# [notice] A new release of pip is available: 24.2 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### 1. vector store

# %%
vector_store = UdaPlayVectorStore(
    persist_dir="./chroma_db/udaplay_games",
    collection_name="udaplay_games",
    reset_collection=True,
)

print(vector_store.collection)
# Out:
# Collection(name=udaplay_games)

# %% [markdown]
# ### 2. Load games

# %%
vector_store.add_games_from_file("data/games.json")
count = vector_store.add_games_from_file("data/games.json")
print(f"Added {count} game records to ChromaDB")
# Out:
# Added 6 game records to ChromaDB

# %%
configure_udaplay_tools(vector_store)
print("UdaPlay tools configured.")
# Out:
# UdaPlay tools configured.

# %% [markdown]
# ### 3. Searching

# %%
query = "Who developed FIFA 21?"
results = vector_store.search_games(query, top_k=1)
results[0]
# Out:
# {'id': 'game_97c9a9a6e97c3d63',
#  'document': 'Title: FIFA 21\nDeveloper: EA Vancouver and EA Romania\nPublisher: Electronic Arts\nRelease Date: October 9, 2020\nPlatforms: Microsoft Windows, PlayStation 4, Xbox One, Nintendo Switch\nGenre: Sports\nDescription: FIFA 21 is a football simulation video game in the FIFA series.',
#  'metadata': {'title': 'FIFA 21',
#   'record_type': 'game',
#   'genre': 'Sports',
#   'source': 'data/games.json',
#   'release_date': 'October 9, 2020',
#   'platforms': 'Microsoft Windows, PlayStation 4, Xbox One, Nintendo Switch',
#   'publisher': 'Electronic Arts',
#   'developer': 'EA Vancouver and EA Romania'},
#  'distance': 0.2696680426597595,
#  'similarity': 0.7303}
